# %%
import pandas as pd

# %%
df_air = pd.read_csv('Air_Quality.csv')
df_air.head()
# Out:
#    Unique_ID  Indicator_ID                    Name Measure Measure_Info  \
# 0     336867           375  Nitrogen dioxide (NO2)    Mean          ppb
# 1     336741           375  Nitrogen dioxide (NO2)    Mean          ppb
# 2     550157           375  Nitrogen dioxide (NO2)    Mean          ppb
# 3     412802           375  Nitrogen dioxide (NO2)    Mean          ppb
# 4     412803           375  Nitrogen dioxide (NO2)    Mean          ppb
#
#   Geo_Type_Name  Geo_Join_ID                     Geo_Place_Name  \
# 0            CD          407      Flushing and Whitestone (CD7)
# 1            CD          107              Upper West Side (CD7)
# 2            CD          414  Rockaway and Broad Channel (CD14)
# 3            CD          407      Flushing and Whitestone (CD7)
# 4            CD          407      Flushing and Whitestone (CD7)
#
#            Time_Period Start_Date  Data_Value  Message
# 0       Winter 2014-15  12/1/2014       23.97      NaN
# ...

# %% [markdown]
# ### Selecting One Column

# %% [markdown]
# #### Syntax 1

# %%
df_air['Name']
# Out:
# 0        Nitrogen dioxide (NO2)
# 1        Nitrogen dioxide (NO2)
# 2        Nitrogen dioxide (NO2)
# 3        Nitrogen dioxide (NO2)
# 4        Nitrogen dioxide (NO2)
#                   ...
# 18857    Nitrogen dioxide (NO2)
# 18858                Ozone (O3)
# 18859                Ozone (O3)
# 18860    Nitrogen dioxide (NO2)
# 18861    Nitrogen dioxide (NO2)
# Name: Name, Length: 18862, dtype: object

# %%
type(df_air['Name']) # gak papa kalo ada spasi juga
# Out:
# pandas.core.series.Series

# %%
df_air['Name'].index
df_air['Name'].head()
# Out:
# 0    Nitrogen dioxide (NO2)
# 1    Nitrogen dioxide (NO2)
# 2    Nitrogen dioxide (NO2)
# 3    Nitrogen dioxide (NO2)
# 4    Nitrogen dioxide (NO2)
# Name: Name, dtype: object

# %% [markdown]
# #### Syntax 2

# %%
df_air.Time_Period # gak bisa kalo misal colom nya ada spasinya
# Out:
# 0             Winter 2014-15
# 1             Winter 2014-15
# 2        Annual Average 2017
# 3             Winter 2015-16
# 4                Summer 2016
#                 ...
# 18857         Winter 2012-13
# 18858            Summer 2015
# 18859            Summer 2019
# 18860         Winter 2019-20
# 18861    Annual Average 2010
# Name: Time_Period, Length: 18862, dtype: object

# %% [markdown]
# ### Select two or more Columns

# %%
df_air[['Name', 'Time_Period']] # pakai double kurung siku [[]]
# Out:
#                          Name          Time_Period
# 0      Nitrogen dioxide (NO2)       Winter 2014-15
# 1      Nitrogen dioxide (NO2)       Winter 2014-15
# 2      Nitrogen dioxide (NO2)  Annual Average 2017
# 3      Nitrogen dioxide (NO2)       Winter 2015-16
# 4      Nitrogen dioxide (NO2)          Summer 2016
# ...                       ...                  ...
# 18857  Nitrogen dioxide (NO2)       Winter 2012-13
# 18858              Ozone (O3)          Summer 2015
# 18859              Ozone (O3)          Summer 2019
# 18860  Nitrogen dioxide (NO2)       Winter 2019-20
# 18861  Nitrogen dioxide (NO2)  Annual Average 2010
#
# [18862 rows x 2 columns]

# %%
type(df_air[['Name', 'Time_Period']])
# Out:
# pandas.core.frame.DataFrame

# %%
df_air[['Name', 'Time_Period', 'Geo_Place_Name']].head()
# Out:
#                      Name          Time_Period  \
# 0  Nitrogen dioxide (NO2)       Winter 2014-15
# 1  Nitrogen dioxide (NO2)       Winter 2014-15
# 2  Nitrogen dioxide (NO2)  Annual Average 2017
# 3  Nitrogen dioxide (NO2)       Winter 2015-16
# 4  Nitrogen dioxide (NO2)          Summer 2016
#
#                       Geo_Place_Name
# 0      Flushing and Whitestone (CD7)
# 1              Upper West Side (CD7)
# 2  Rockaway and Broad Channel (CD14)
# 3      Flushing and Whitestone (CD7)
# 4      Flushing and Whitestone (CD7)

# %%
## df_air.'Name', 'Geo_Place_Name' # gak bisa kalo pake date sign aja gak bisa pake titik doang

# %% [markdown]
# ### Adding New Column

# %%
df_air['Kewaspadaan'] = 0
df_air.head()
# Out:
#    Unique_ID  Indicator_ID                    Name Measure Measure_Info  \
# 0     336867           375  Nitrogen dioxide (NO2)    Mean          ppb
# 1     336741           375  Nitrogen dioxide (NO2)    Mean          ppb
# 2     550157           375  Nitrogen dioxide (NO2)    Mean          ppb
# 3     412802           375  Nitrogen dioxide (NO2)    Mean          ppb
# 4     412803           375  Nitrogen dioxide (NO2)    Mean          ppb
#
#   Geo_Type_Name  Geo_Join_ID                     Geo_Place_Name  \
# 0            CD          407      Flushing and Whitestone (CD7)
# 1            CD          107              Upper West Side (CD7)
# 2            CD          414  Rockaway and Broad Channel (CD14)
# 3            CD          407      Flushing and Whitestone (CD7)
# 4            CD          407      Flushing and Whitestone (CD7)
#
#            Time_Period Start_Date  Data_Value  Message    Type  Kewaspadaan
# ...

# %%
import numpy as np

# %%
Kewaspadaan = (np.arange(0, 18862)) # membuat data array dengan nupy menggunakan range

# %%
df_air['Kewaspadaan'] = Kewaspadaan
df_air.head()
# Out:
#    Unique_ID  Indicator_ID                    Name Measure Measure_Info  \
# 0     336867           375  Nitrogen dioxide (NO2)    Mean          ppb
# 1     336741           375  Nitrogen dioxide (NO2)    Mean          ppb
# 2     550157           375  Nitrogen dioxide (NO2)    Mean          ppb
# 3     412802           375  Nitrogen dioxide (NO2)    Mean          ppb
# 4     412803           375  Nitrogen dioxide (NO2)    Mean          ppb
#
#   Geo_Type_Name  Geo_Join_ID                     Geo_Place_Name  \
# 0            CD          407      Flushing and Whitestone (CD7)
# 1            CD          107              Upper West Side (CD7)
# 2            CD          414  Rockaway and Broad Channel (CD14)
# 3            CD          407      Flushing and Whitestone (CD7)
# 4            CD          407      Flushing and Whitestone (CD7)
#
#            Time_Period Start_Date  Data_Value  Message    Type  Kewaspadaan
# ...

# %%
int_kewas = np.random.randint(1, 100, size=18862) # membuat radom nuber menggunakan numpy

# %%
df_air['Kewaspadaan'] = int_kewas
df_air.head()
# Out:
#    Unique_ID  Indicator_ID                    Name Measure Measure_Info  \
# 0     336867           375  Nitrogen dioxide (NO2)    Mean          ppb
# 1     336741           375  Nitrogen dioxide (NO2)    Mean          ppb
# 2     550157           375  Nitrogen dioxide (NO2)    Mean          ppb
# 3     412802           375  Nitrogen dioxide (NO2)    Mean          ppb
# 4     412803           375  Nitrogen dioxide (NO2)    Mean          ppb
#
#   Geo_Type_Name  Geo_Join_ID                     Geo_Place_Name  \
# 0            CD          407      Flushing and Whitestone (CD7)
# 1            CD          107              Upper West Side (CD7)
# 2            CD          414  Rockaway and Broad Channel (CD14)
# 3            CD          407      Flushing and Whitestone (CD7)
# 4            CD          407      Flushing and Whitestone (CD7)
#
#            Time_Period Start_Date  Data_Value  Message    Type  Kewaspadaan
# ...

# %%
 np.random.uniform(1, 100, size=18862) # float nya ini
# Out:
# array([70.86660371, 38.96147946, 37.47734141, ..., 69.47942979,
#        73.32990295, 21.29866599])
